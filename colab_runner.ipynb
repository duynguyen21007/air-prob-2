# %% [markdown]
# # Viettel AI Race - Problem 2 (Local LLM on Colab)
# This notebook is configured to run the LLM reranker locally on a Colab T4 GPU using 4-bit quantization and Google Drive caching.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !pip install -r requirements.txt

# %%
# Run Stage 4 RxNorm
# !python scripts/run_stage4_rxnorm.py

# %%
# Run Stage 5 ICD-10
# !python scripts/run_stage5_icd10.py
